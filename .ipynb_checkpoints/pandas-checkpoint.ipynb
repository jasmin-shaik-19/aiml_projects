# %% [markdown]
# what is pandas ?
# pandasnis a python library used for data cleaning,analysis,and manupilation.
# works like excel but faster.
# helps loads the data ,clean,filter,analyze data.
# uses: data science.ml.finance,analytics,and automating data tasks.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# pandas data structures
# series---one dimensional coloumn
# dataframe---table with rows + columns

# %%
s=pd.Series([10,2,32,23])
s
# Out:
# 0    10
# 1     2
# 2    32
# 3    23
# dtype: int64

# %% [markdown]
# READING CSV FILES

# %%
df=pd.DataFrame({
    "name":["jasmin","yasmin"],
    "age":[20,19]
})
print(df)
# Out:
#      name  age
# 0  jasmin   20
# 1  yasmin   19

# %%
student={
    "name":["jasmin","yasmin","mubina","zoya","zara"],
    "rollno":[1,2,3,4,5],
     "dept":["cse","ece","cse","cse","ece"]
}
pd.DataFrame(student)
# Out:
#      name  rollno dept
# 0  jasmin       1  cse
# 1  yasmin       2  ece
# 2  mubina       3  cse
# 3    zoya       4  cse
# 4    zara       5  ece

# %%
import pandas as pd
pd.read_csv("weather_data.csv")
# Out:
#          Date          City  Temperature_C  Humidity_% Condition
# 0  01-01-2025      Hyderbad           28.0        60.0     Sunny
# 1  02-01-2025    Vijayawada           29.0        62.0     Sunny
# 2  03-01-2025  Viskhapatnam            NaN        58.0    Cloudy
# 3  04-01-2025      Kakinada           31.0        55.0    Cloudy
# 4  05-01-2025      Banglore            NaN        57.0     Rainy
# 5  06-01-2025        Mumbai           33.0         NaN     Rainy
# 6  07-01-2025       Chennai           34.0        61.0     Sunny
# 7  08-01-2025    Rajamundry           32.0        63.0    Cloudy
# 8  09-01-2025         Eluru            NaN        64.0     Rainy
# 9  10-01-2025    Anakapalli           29.0        62.0     Sunny

# %% [markdown]
# reading excel file

# %%
df=pd.read_excel("weather_data_XL.xlsx")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %% [markdown]
# writing the data into files
# df.to_csv("data.csv",index=false)
# df.to_excel("new.xlsx",sheet_name="weather_data",index=false)

# %%
#save file as csv and name is data.csv and save the file wih preventing row numbers from being saved.
df.to_csv("data.csv",index=False)

# %%
df.to_excel("new.xlsx",sheet_name="weather_data",index=False)

# %%
#first five rows
df.head()
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 0 2025-01-01  Hyderbad             28          60     Sunny
# 1 2025-01-02  Hyderbad             29          62     Sunny
# 2 2025-01-03  Hyderbad             30          58    Cloudy
# 3 2025-01-04  Hyderbad             31          55    Cloudy
# 4 2025-01-05  Banglore             32          57     Rainy

# %%
df.head(10)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.tail()
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.tail(3)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           10 non-null     datetime64[ns]
#  1   City           10 non-null     object
#  2   Temperature_C  10 non-null     int64
#  3   Humidity_%     10 non-null     int64
#  4   Condition      10 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df["Date"]
# Out:
# 0   2025-01-01
# 1   2025-01-02
# 2   2025-01-03
# 3   2025-01-04
# 4   2025-01-05
# 5   2025-01-06
# 6   2025-01-07
# 7   2025-01-08
# 8   2025-01-09
# 9   2025-01-10
# Name: Date, dtype: datetime64[ns]

# %%
df.Date
# Out:
# 0   2025-01-01
# 1   2025-01-02
# 2   2025-01-03
# 3   2025-01-04
# 4   2025-01-05
# 5   2025-01-06
# 6   2025-01-07
# 7   2025-01-08
# 8   2025-01-09
# 9   2025-01-10
# Name: Date, dtype: datetime64[ns]

# %%
df.shape
# Out:
# (10, 5)

# %%
df[4:8]
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 4 2025-01-05  Banglore             32          57     Rainy
# 5 2025-01-06  Banglore             33          59     Rainy
# 6 2025-01-07  Banglore             34          61     Sunny
# 7 2025-01-08  Banglore             32          63    Cloudy

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Temperature_C', 'Humidity_%', 'Condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.dtypes
# Out:
# Date             datetime64[ns]
# City                     object
# Temperature_C             int64
# Humidity_%                int64
# Condition                object
# dtype: object

# %%
df[["Date","Condition"]]
# Out:
#         Date Condition
# 0 2025-01-01     Sunny
# 1 2025-01-02     Sunny
# 2 2025-01-03    Cloudy
# 3 2025-01-04    Cloudy
# 4 2025-01-05     Rainy
# 5 2025-01-06     Rainy
# 6 2025-01-07     Sunny
# 7 2025-01-08    Cloudy
# 8 2025-01-09     Rainy
# 9 2025-01-10     Sunny

# %% [markdown]
# MISSING VALUES

# %%
df.isnull() #check missing values
# Out:
#     Date   City  Temperature_C  Humidity_%  Condition
# 0  False  False          False       False      False
# 1  False  False          False       False      False
# 2  False  False          False       False      False
# 3  False  False          False       False      False
# 4  False  False          False       False      False
# 5  False  False          False       False      False
# 6  False  False          False       False      False
# 7  False  False          False       False      False
# 8  False  False          False       False      False
# 9  False  False          False       False      False

# %%
import pandas as pd
df=pd.read_csv("weather_data.csv")

# %%
df.isnull()
# Out:
#     Date   City  Temperature_C  Humidity_%  Condition
# 0  False  False          False       False      False
# 1  False  False          False       False      False
# 2  False  False           True       False      False
# 3  False  False          False       False      False
# 4  False  False           True       False      False
# 5  False  False          False        True      False
# 6  False  False          False       False      False
# 7  False  False          False       False      False
# 8  False  False           True       False      False
# 9  False  False          False       False      False

# %%
df.isnull().sum()
# Out:
# Date             0
# City             0
# Temperature_C    3
# Humidity_%       1
# Condition        0
# dtype: int64

# %%
df=pd.DataFrame({
    "name":["jasmin","yasmin","mubina"],
    "age":[20,19,None]})
df
# Out:
#      name   age
# 0  jasmin  20.0
# 1  yasmin  19.0
# 2  mubina   NaN

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False   True

# %% [markdown]
# HANDLING MISSING VALUES

# %%
df["age"]=df["age"].fillna(df["age"].mean())
df
# Out:
#      name   age
# 0  jasmin  20.0
# 1  yasmin  19.0
# 2  mubina  19.5

# %%
df=pd.DataFrame({
    "name":["jasmin","yasmin","mubina"],
    "age":[20,19,None]})
df
# Out:
#      name   age
# 0  jasmin  20.0
# 1  yasmin  19.0
# 2  mubina   NaN

# %%
df_clean=df.dropna()
df_clean
# Out:
#      name   age
# 0  jasmin  20.0
# 1  yasmin  19.0

# %% [markdown]
# DUPLICATES

# %%
df=pd.DataFrame({
    "name":["jasmin","yasmin","jasmin"],
    "regs":[201,191,201]})
df
# Out:
#      name  regs
# 0  jasmin   201
# 1  yasmin   191
# 2  jasmin   201

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df=df.drop_duplicates()
df
# Out:
#      name  regs
# 0  jasmin   201
# 1  yasmin   191

# %% [markdown]
# STATISTICS

# %%
df=pd.read_excel("weather_data_XL.xlsx")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df["Temperature_C"].std()
# Out:
# 1.911950719959998

# %%
df["Temperature_C"].var()
# Out:
# 3.6555555555555554

# %%
df["Temperature_C"].max()
# Out:
# 34

# %%
df["Temperature_C"].min()
# Out:
# 28

# %%
df["Temperature_C"].mean()
# Out:
# 30.9

# %%
df["Temperature_C"].describe()
# Out:
# count    10.000000
# mean     30.900000
# std       1.911951
# min      28.000000
# 25%      29.250000
# 50%      31.000000
# 75%      32.000000
# max      34.000000
# Name: Temperature_C, dtype: float64

# %%
df[df.Temperature_C==df.Temperature_C.max()]
# Out:
#         Date      City  Temperature_C  Humidity_% Condition
# 6 2025-01-07  Banglore             34          61     Sunny

# %%
df.City[df.Temperature_C==df.Temperature_C.max()]
# Out:
# 6    Banglore
# Name: City, dtype: object

# %%
df.count()
# Out:
# Date             10
# City             10
# Temperature_C    10
# Humidity_%       10
# Condition        10
# dtype: int64

# %%
df["City"].nunique()
# Out:
# 3

# %%
df["City"].value_counts()
# Out:
# City
# Hyderbad      4
# Banglore      4
# Vijayawada    2
# Name: count, dtype: int64

# %% [markdown]
# STRING CLEANING

# %%
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    Hyderbad             28          60     Sunny
# 1 2025-01-02    Hyderbad             29          62     Sunny
# 2 2025-01-03    Hyderbad             30          58    Cloudy
# 3 2025-01-04    Hyderbad             31          55    Cloudy
# 4 2025-01-05    Banglore             32          57     Rainy
# 5 2025-01-06    Banglore             33          59     Rainy
# 6 2025-01-07    Banglore             34          61     Sunny
# 7 2025-01-08    Banglore             32          63    Cloudy
# 8 2025-01-09  Vijayawada             31          64     Rainy
# 9 2025-01-10  Vijayawada             29          62     Sunny

# %%
df["City"]=df["City"].str.lower()
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    hyderbad             28          60     Sunny
# 1 2025-01-02    hyderbad             29          62     Sunny
# 2 2025-01-03    hyderbad             30          58    Cloudy
# 3 2025-01-04    hyderbad             31          55    Cloudy
# 4 2025-01-05    banglore             32          57     Rainy
# 5 2025-01-06    banglore             33          59     Rainy
# 6 2025-01-07    banglore             34          61     Sunny
# 7 2025-01-08    banglore             32          63    Cloudy
# 8 2025-01-09  vijayawada             31          64     Rainy
# 9 2025-01-10  vijayawada             29          62     Sunny

# %%
df["City"]=df["City"].str.upper()
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01    HYDERBAD             28          60     Sunny
# 1 2025-01-02    HYDERBAD             29          62     Sunny
# 2 2025-01-03    HYDERBAD             30          58    Cloudy
# 3 2025-01-04    HYDERBAD             31          55    Cloudy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny

# %%
df["City"]=df["City"].str.replace("HYDERBAD","CHENNAI")
df
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01     CHENNAI             28          60     Sunny
# 1 2025-01-02     CHENNAI             29          62     Sunny
# 2 2025-01-03     CHENNAI             30          58    Cloudy
# 3 2025-01-04     CHENNAI             31          55    Cloudy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny

# %%
df.sort_values(by="Temperature_C",ascending=True)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01     CHENNAI             28          60     Sunny
# 1 2025-01-02     CHENNAI             29          62     Sunny
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny
# 2 2025-01-03     CHENNAI             30          58    Cloudy
# 3 2025-01-04     CHENNAI             31          55    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny

# %%
df.sort_values(by="Temperature_C",ascending=False)
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 6 2025-01-07    BANGLORE             34          61     Sunny
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 3 2025-01-04     CHENNAI             31          55    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 2 2025-01-03     CHENNAI             30          58    Cloudy
# 1 2025-01-02     CHENNAI             29          62     Sunny
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny
# 0 2025-01-01     CHENNAI             28          60     Sunny

# %%
df.sort_values(by=["Temperature_C","Humidity_%"],ascending=[True,True])
# Out:
#         Date        City  Temperature_C  Humidity_% Condition
# 0 2025-01-01     CHENNAI             28          60     Sunny
# 1 2025-01-02     CHENNAI             29          62     Sunny
# 9 2025-01-10  VIJAYAWADA             29          62     Sunny
# 2 2025-01-03     CHENNAI             30          58    Cloudy
# 3 2025-01-04     CHENNAI             31          55    Cloudy
# 8 2025-01-09  VIJAYAWADA             31          64     Rainy
# 4 2025-01-05    BANGLORE             32          57     Rainy
# 7 2025-01-08    BANGLORE             32          63    Cloudy
# 5 2025-01-06    BANGLORE             33          59     Rainy
# 6 2025-01-07    BANGLORE             34          61     Sunny
